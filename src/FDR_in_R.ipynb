# %%
data_df <- read.csv('../data/fecal_mouse_metabolites_scaled.glmer.txt', sep="\t")
p <- data_df["pval"]
p <- as.numeric(unlist(p))
p.adjust(p, method = "BH", n = length(p))
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”
#   [1] 0.7508906 0.9609341 1.0000000 0.7973400 0.8136768 0.7992900 1.0000000
#   [8] 1.0000000 1.0000000 0.7573552 0.8237413 0.9916637 0.9314158 1.0000000
#  [15] 0.7973400 0.8237413 0.8638480 0.7896821 0.7661747 0.7573796 0.8133629
#  [22] 0.7892721 0.7508906 0.7503843 1.0000000 0.7503843 0.7503843 0.7503843
#  [29] 0.7503843 0.7503843 0.7503843 0.7837517 0.9314158 0.9988010 0.8133629
#  [36] 0.7608024 0.9477925 1.0000000 0.7503843 1.0000000 0.7566449 1.0000000
#  [43] 0.7503843 0.7503843 1.0000000 1.0000000 0.9477925 0.7503843 0.8237413
#  [50] 0.7503843 0.7508906 0.7503843 0.7503843 0.7508906 0.7992900 0.7503843
#  [57] 0.7503843 0.7553427 0.7973400 0.7503843 0.8264263 0.7949753 0.7503843
#  [64] 0.7503843 0.7508906 0.9318245 0.7503843 0.7503843 0.7503843 0.7503843
#  [71] 0.8708220 1.0000000 0.7992900 0.7503843 0.8237408 0.7508906        NA
# ...
